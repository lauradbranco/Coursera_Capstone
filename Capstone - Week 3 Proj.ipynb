# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ## Part 1

# %% [markdown]
# This notebook contains the procedures involved in the first part of the assignment. Before we do anything else, we must import the necessary packages.

# %%
import sys
# !{sys.executable} -m pip install geopy folium
import numpy as np
import pandas as pd
import json
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (1.21.0)
# Requirement already satisfied: folium in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (0.10.1)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from geopy) (1.50)
# Requirement already satisfied: numpy in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from folium) (1.15.1)
# Requirement already satisfied: jinja2>=2.9 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from folium) (2.10)
# Requirement already satisfied: branca>=0.3.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from folium) (0.4.0)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from folium) (2.19.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from branca>=0.3.0->folium) (1.11.0)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->folium) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->folium) (2018.8.24)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->folium) (1.23)
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# Libraries imported.

# %% [markdown]
# ### Scrape Wikipedia page

# %% [markdown]
# Now we can begin the assignment. The first step will be to collect the Toronto neighborhood data from a Wikipedia page. We will do this using the read_html function in pandas. Since this function will return our data as a list of data frames, we will also have to unite them all into a single data frame using the concatenate function.

# %%
import pandas as pd
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
dfs = pd.read_html(url) 
df = pd.concat(dfs)
df.columns = df.iloc[0]
df = df.drop(df.index[0])
df.head()
# Out:
# 0 Postcode           Borough     Neighbourhood  NaN  NaN  NaN  NaN  NaN  NaN  \
# 1      M1A      Not assigned      Not assigned  NaN  NaN  NaN  NaN  NaN  NaN
# 2      M2A      Not assigned      Not assigned  NaN  NaN  NaN  NaN  NaN  NaN
# 3      M3A        North York         Parkwoods  NaN  NaN  NaN  NaN  NaN  NaN
# 4      M4A        North York  Victoria Village  NaN  NaN  NaN  NaN  NaN  NaN
# 5      M5A  Downtown Toronto      Harbourfront  NaN  NaN  NaN  NaN  NaN  NaN
#
# 0  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5  NaN ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Remove unassigned postal codes

# %% [markdown]
# As you can see, in the last step, we obtained a dataframe with the information from the Wikipedia page. The data we need are actually in the final three columns of this data frame, and we will therefore select them and view them in the following step. We will also take the opportunity to remove rows where a post code has not been assigned, as well as rows containing 'NaN' values.

# %%
df = df[['Borough','Neighbourhood','Postcode']]
to_drop = ['Not assigned']
df = df[~df['Borough'].isin(to_drop)].dropna()
df.head()
# Out:
# 0           Borough     Neighbourhood Postcode
# 3        North York         Parkwoods      M3A
# 4        North York  Victoria Village      M4A
# 5  Downtown Toronto      Harbourfront      M5A
# 6        North York  Lawrence Heights      M6A
# 7        North York    Lawrence Manor      M6A

# %% [markdown]
# ### Group neighborhoods by postal code

# %% [markdown]
# Our next step is to group all neighborhoods which share the same postal code. We will do this using the groupby function, joining rows by postal code and borough. We will also take the opportunity to rename the postal code column, so it looks like the template in the task instructions.

# %%
df2 = df[df.duplicated('Postcode', keep=False)].groupby(['Postcode','Borough'])['Neighbourhood'].apply(', '.join).reset_index()
df2.rename(columns={'Postcode': "PostalCode",'Neighbourhood':'Neighborhood'}, inplace=True)
df2 = df2.drop([df2.index[0] , df2.index[57]])
df2.head(10)
# Out:
#    PostalCode      Borough                                       Neighborhood
# 1         M1B  Scarborough                                     Rouge, Malvern
# 2         M1C  Scarborough             Highland Creek, Rouge Hill, Port Union
# 3         M1E  Scarborough                  Guildwood, Morningside, West Hill
# 4         M1K  Scarborough        East Birchmount Park, Ionview, Kennedy Park
# 5         M1L  Scarborough                    Clairlea, Golden Mile, Oakridge
# 6         M1M  Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# 7         M1N  Scarborough                        Birch Cliff, Cliffside West
# 8         M1P  Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# 9         M1R  Scarborough                                  Maryvale, Wexford
# 10        M1T  Scarborough            Clarks Corners, Sullivan, Tam O'Shanter

# %% [markdown]
# ### Finding the shape of the final data frame

# %% [markdown]
# The data frame now looks like the example provided. The final step is to use the shape function to look at the dimensions of our dataframe.

# %%
df2.shape
# Out:
# (56, 3)

# %% [markdown]
# You have reached the end of Part 1. Now we will go on to Part 2.

# %% [markdown]
# ## Part 2

# %% [markdown]
# Our first step will be to get the latitude and longitude information for each postal code from a CSV file we will download from the task instructions.

# %%
url="https://cocl.us/Geospatial_data"
coords=pd.read_csv(url)
coords.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Our next step will be to join both dataframes using the Postal Code column as the key, in order to obtain a single data frame with information about neighborhoods and location.

# %%
neighborhoods = pd.merge(df2, coords, left_on='PostalCode',right_on='Postal Code',validate='many_to_one')
neighborhoods.drop(columns=['Postal Code'], inplace=True)
neighborhoods.head(10)
# Out:
#   PostalCode      Borough                                       Neighborhood  \
# 0        M1B  Scarborough                                     Rouge, Malvern
# 1        M1C  Scarborough             Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough                  Guildwood, Morningside, West Hill
# 3        M1K  Scarborough        East Birchmount Park, Ionview, Kennedy Park
# 4        M1L  Scarborough                    Clairlea, Golden Mile, Oakridge
# 5        M1M  Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# 6        M1N  Scarborough                        Birch Cliff, Cliffside West
# 7        M1P  Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# 8        M1R  Scarborough                                  Maryvale, Wexford
# 9        M1T  Scarborough            Clarks Corners, Sullivan, Tam O'Shanter
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.727929 -79.262029
# 4  43.711112 -79.284577
# 5  43.716316 -79.239476
# 6  43.692657 -79.264848
# 7  43.757410 -79.273304
# 8  43.750072 -79.295849
# 9  43.781638 -79.304302

# %% [markdown]
# ## Part 3

# %% [markdown]
# Now we are ready to learn more about each neighborhood, in order to later cluster them. Our first step will be to find the coordinates of the city of Toronto, in order to build our map.

# %%
address = 'Toronto, ON'

from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinates of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinates of Toronto are 43.653963, -79.387207.

# %% [markdown]
# ### Plotting the neighborhoods on a map

# %% [markdown]
# Using the information we just collected, together with our previous data on the coordinates of each neighborhoood, we will build a map that contains markers for each set of neighborhoods which share a postal code.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Collecting information about venues in each neighborhood

# %% [markdown]
# Now we will define a function that will get information for venues in each of our neighborhoods. This will be done through the Foursquare API.

# %%
# @hidden_cell
CLIENT_ID = 'IHGBJCBT31RG1UETAVMPTBVUXVN4MFG5UTM0BBTO0NPCRL50' # your Foursquare ID
CLIENT_SECRET = '0IGTFFK55WAAI4FGSYVC3YMH121RT3GGSVXG2LRQK5O3W0FO' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# We will apply the function and give it some additional instructions, in order to create a dataframe containing information about venues in each of the neighborhoods we have found.

# %%
neighborhood_latitude = neighborhoods.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = neighborhoods.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = neighborhoods.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))

LIMIT = 255

toronto_venues = getNearbyVenues(names=neighborhoods['Neighborhood'],
                                   latitudes=neighborhoods['Latitude'],
                                   longitudes=neighborhoods['Longitude']
                                  )
toronto_venues
# Out:
# Latitude and longitude values of Rouge, Malvern are 43.806686299999996, -79.19435340000001.
# Rouge, Malvern
# Highland Creek, Rouge Hill, Port Union
# Guildwood, Morningside, West Hill
# East Birchmount Park, Ionview, Kennedy Park
# Clairlea, Golden Mile, Oakridge
# Cliffcrest, Cliffside, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Scarborough Town Centre, Wexford Heights
# Maryvale, Wexford
# Clarks Corners, Sullivan, Tam O'Shanter
# Agincourt North, L'Amoreaux East, Milliken, Steeles East
# Fairview, Henry Farm, Oriole
# Silver Hills, York Mills
# Newtonbrook, Willowdale
# Flemingdon Park, Don Mills South
# Bathurst Manor, Downsview North, Wilson Heights
# Northwood Park, York University
# CFB Toronto, Downsview East
# Woodbine Gardens, Parkview Hill
# The Danforth West, Riverdale
# The Beaches West, India Bazaar
# Moore Park, Summerhill East
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# Cabbagetown, St. James Town
# Ryerson, Garden District
# Adelaide, King, Richmond
# Harbourfront East, Toronto Islands, Union Station
# Design Exchange, Toronto Dominion Centre
# Commerce Court, Victoria Hotel
# Bedford Park, Lawrence Manor East
# Forest Hill North, Forest Hill West
# The Annex, North Midtown, Yorkville
# Harbord, University of Toronto
# Chinatown, Grange Park, Kensington Market
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# First Canadian Place, Underground city
# Lawrence Heights, Lawrence Manor
# Dovercourt Village, Dufferin
# Little Portugal, Trinity
# Brockton, Exhibition Place, Parkdale Village
# Downsview, North Park, Upwood Park
# Del Ray, Keelesdale, Mount Dennis, Silverthorn
# The Junction North, Runnymede
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Humber Bay Shores, Mimico South, New Toronto
# Alderwood, Long Branch
# The Kingsway, Montgomery Road, Old Mill North
# Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea
# Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe
# Emery, Humberlea
# Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips
# Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown
#                                            Neighborhood  \
# 0                                        Rouge, Malvern
# 1                Highland Creek, Rouge Hill, Port Union
# 2                Highland Creek, Rouge Hill, Port Union
# 3                     Guildwood, Morningside, West Hill
# 4                     Guildwood, Morningside, West Hill
# 5                     Guildwood, Morningside, West Hill
# 6                     Guildwood, Morningside, West Hill
# 7                     Guildwood, Morningside, West Hill
# 8                     Guildwood, Morningside, West Hill
# 9                     Guildwood, Morningside, West Hill
# 10          East Birchmount Park, Ionview, Kennedy Park
# 11          East Birchmount Park, Ionview, Kennedy Park
# 12          East Birchmount Park, Ionview, Kennedy Park
# 13          East Birchmount Park, Ionview, Kennedy Park
# 14          East Birchmount Park, Ionview, Kennedy Park
# 15                      Clairlea, Golden Mile, Oakridge
# 16                      Clairlea, Golden Mile, Oakridge
# 17                      Clairlea, Golden Mile, Oakridge
# 18                      Clairlea, Golden Mile, Oakridge
# 19                      Clairlea, Golden Mile, Oakridge
# 20                      Clairlea, Golden Mile, Oakridge
# 21                      Clairlea, Golden Mile, Oakridge
# 22                      Clairlea, Golden Mile, Oakridge
# 23                      Clairlea, Golden Mile, Oakridge
# 24      Cliffcrest, Cliffside, Scarborough Village West
# 1345                  The Beer Store       43.741694       -79.584373
# 1346                       No Frills       43.741696       -79.584379
# 1347                     Pizza Pizza       43.741569       -79.584489
# 1348                  Sunny Foodmart       43.741840       -79.590561
# 1349                      McDonald's       43.741757       -79.584230
#
#                      Venue Category
# 0              Fast Food Restaurant
# 1                               Bar
# 2                    History Museum
# 3                 Electronics Store
# 4                               Spa
# 5                Mexican Restaurant
# 6               Rental Car Location
# 7                    Medical Center
# 8                      Intersection
# 9                    Breakfast Spot
# 10                 Department Store
# 11                      Coffee Shop
# 12                   Discount Store
# 13                       Hobby Shop
# 14                   Discount Store
# 15                   Ice Cream Shop
# 16                     Intersection
# 17                         Bus Line
# 18                    Metro Station
# 19                         Bus Line
# 20                      Bus Station
# 21                           Bakery
# 22                           Bakery
# 23                     Soccer Field
# 24                            Motel
# 25              American Restaurant
# 26                             Café
# 27            General Entertainment
# 28                     Skating Rink
# 29                  College Stadium
# ...                             ...
# 1320                 Sandwich Place
# 1321                  Grocery Store
# 1322                 Hardware Store
# 1323                     Kids Store
# 1324                            Gym
# 1325                  Burrito Place
# 1326                     Print Shop
# 1327                   Liquor Store
# 1328                    Coffee Shop
# 1329                     Beer Store
# 1330                 Cosmetics Shop
# 1331                    Pizza Place
# 1332                           Café
# 1333              Convenience Store
# 1334                 Shopping Plaza
# 1335                           Park
# 1336                 Baseball Field
# 1337  Paper / Office Supplies Store
# 1338                 Sandwich Place
# 1339                       Bus Line
# 1340                    Pizza Place
# 1341              Mobile Phone Shop
# 1342                 Sandwich Place
# 1343                       Pharmacy
# 1344            Fried Chicken Joint
# 1345                     Beer Store
# 1346                  Grocery Store
# 1347                    Pizza Place
# 1348                  Grocery Store
# 1349           Fast Food Restaurant
#
# [1350 rows x 7 columns]

# %% [markdown]
# Let's look at how many types of venue we found in total:

# %%
print('There are {} unique categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 225 unique categories.

# %% [markdown]
# Our next step is to use one-hot encoding to obtain a clearer description of the types of venues our neighborhoods.

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood']

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.head(10)
# Out:
#                                         Neighborhood  Accessories Store  \
# 0                           Adelaide, King, Richmond                0.0
# 1  Agincourt North, L'Amoreaux East, Milliken, St...                0.0
# 2  Albion Gardens, Beaumond Heights, Humbergate, ...                0.0
# 3                             Alderwood, Long Branch                0.0
# 4    Bathurst Manor, Downsview North, Wilson Heights                0.0
# 5                  Bedford Park, Lawrence Manor East                0.0
# 6                        Birch Cliff, Cliffside West                0.0
# 7  Bloordale Gardens, Eringate, Markland Wood, Ol...                0.0
# 8       Brockton, Exhibition Place, Parkdale Village                0.0
# 9                        CFB Toronto, Downsview East                0.0
#
#     Airport  Airport Food Court  Airport Gate  Airport Lounge  \
# 0  0.000000                 0.0           0.0             0.0
# 1  0.000000                 0.0           0.0             0.0
# 2  0.000000                 0.0           0.0             0.0
# 3  0.000000                 0.0           0.0             0.0
# 4  0.000000                 0.0           0.0             0.0
# 5  0.000000                 0.0           0.0             0.0
# 6  0.000000                 0.0           0.0             0.0
# 7  0.000000                 0.0           0.0             0.0
# 8  0.000000                 0.0           0.0             0.0
# 9  0.333333                 0.0           0.0             0.0
#
#    Airport Service  Airport Terminal  American Restaurant  Aquarium  \
# 0              0.0               0.0             0.020000       0.0
# 1              0.0               0.0             0.000000       0.0
# 2              0.0               0.0             0.000000       0.0
# 3              0.0               0.0             0.000000       0.0
# 4              0.0               0.0             0.000000       0.0
# 5              0.0               0.0             0.041667       0.0
# 6              0.0               0.0             0.000000       0.0
# 7              0.0               0.0             0.000000       0.0
# 8              0.0               0.0             0.000000       0.0
# 9              0.0               0.0             0.000000       0.0
#
#       ...       Trail  Train Station  Vegetarian / Vegan Restaurant  \
# 0     ...         0.0            0.0                           0.02
# 1     ...         0.0            0.0                           0.00
# 2     ...         0.0            0.0                           0.00
# 3     ...         0.0            0.0                           0.00
# 4     ...         0.0            0.0                           0.00
# 5     ...         0.0            0.0                           0.00
# 6     ...         0.0            0.0                           0.00
# 7     ...         0.0            0.0                           0.00
# 8     ...         0.0            0.0                           0.00
# 9     ...         0.0            0.0                           0.00
#
#    Video Game Store  Video Store  Vietnamese Restaurant  Wine Bar  \
# 0               0.0     0.000000                    0.0      0.01
# 1               0.0     0.000000                    0.0      0.00
# 2               0.0     0.000000                    0.0      0.00
# 3               0.0     0.000000                    0.0      0.00
# 4               0.0     0.052632                    0.0      0.00
# 5               0.0     0.000000                    0.0      0.00
# 6               0.0     0.000000                    0.0      0.00
# 7               0.0     0.000000                    0.0      0.00
# 8               0.0     0.000000                    0.0      0.00
# 9               0.0     0.000000                    0.0      0.00
#
#    Wings Joint  Women's Store  Yoga Studio
# 0          0.0           0.01     0.000000
# 1          0.0           0.00     0.000000
# 2          0.0           0.00     0.000000
# 3          0.0           0.00     0.000000
# 4          0.0           0.00     0.000000
# 5          0.0           0.00     0.000000
# 6          0.0           0.00     0.000000
# 7          0.0           0.00     0.000000
# 8          0.0           0.00     0.041667
# 9          0.0           0.00     0.000000
#
# [10 rows x 225 columns]

# %% [markdown]
# Now, let us create a function that will sort the frequency of the venues.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# We can now use our function to obtain the 10 most common venue types for each postal code location.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                           Adelaide, King, Richmond           Coffee Shop
# 1  Agincourt North, L'Amoreaux East, Milliken, St...                  Park
# 2  Albion Gardens, Beaumond Heights, Humbergate, ...         Grocery Store
# 3                             Alderwood, Long Branch           Pizza Place
# 4    Bathurst Manor, Downsview North, Wilson Heights           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0            Restaurant                  Café       Thai Restaurant
# 1            Playground           Yoga Studio    Dim Sum Restaurant
# 2              Pharmacy  Fast Food Restaurant        Sandwich Place
# 3              Pharmacy    Athletics & Sports           Coffee Shop
# 4         Shopping Mall    Frozen Yogurt Shop           Bridal Shop
#
#   5th Most Common Venue 6th Most Common Venue      7th Most Common Venue  \
# 0      Sushi Restaurant                   Bar           Asian Restaurant
# 1           Event Space  Ethiopian Restaurant          Electronics Store
# 2            Beer Store   Fried Chicken Joint                Pizza Place
# 3                  Pool                   Pub             Sandwich Place
# 4            Restaurant                 Diner  Middle Eastern Restaurant
#
#          8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                       Lounge        Cosmetics Shop     Seafood Restaurant
# 1  Eastern European Restaurant   Dumpling Restaurant             Donut Shop
# 2  Eastern European Restaurant   Dumpling Restaurant     Dim Sum Restaurant
# 3                 Skating Rink                   Gym               Aquarium
# 4                Deli / Bodega                  Bank            Supermarket

# %% [markdown]
# ### Clustering the neighborhoods

# %% [markdown]
# First we will cluster the neighborhoods into five different types according to the top 10 venues in each location.

# %%
# set number of clusters
kclusters = 12

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:20]
# Out:
# array([4, 6, 1, 1, 4, 4, 9, 4, 4, 4, 4, 4, 4, 4, 1, 7, 3, 4, 4, 4],
#       dtype=int32)

# %% [markdown]
# Now we will create a dataframe to show us our clusters.

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'ClusterLabels', kmeans.labels_)

toronto_merged = neighborhoods

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head(10) # check the last columns!
# Out:
#   PostalCode      Borough                                       Neighborhood  \
# 0        M1B  Scarborough                                     Rouge, Malvern
# 1        M1C  Scarborough             Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough                  Guildwood, Morningside, West Hill
# 3        M1K  Scarborough        East Birchmount Park, Ionview, Kennedy Park
# 4        M1L  Scarborough                    Clairlea, Golden Mile, Oakridge
# 5        M1M  Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# 6        M1N  Scarborough                        Birch Cliff, Cliffside West
# 7        M1P  Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# 8        M1R  Scarborough                                  Maryvale, Wexford
# 9        M1T  Scarborough            Clarks Corners, Sullivan, Tam O'Shanter
#
#     Latitude  Longitude  ClusterLabels 1st Most Common Venue  \
# 0  43.806686 -79.194353            2.0  Fast Food Restaurant
# 1  43.784535 -79.160497           10.0        History Museum
# 2  43.763573 -79.188711            4.0   Rental Car Location
# 3  43.727929 -79.262029           11.0        Discount Store
# 4  43.711112 -79.284577            4.0                Bakery
# 5  43.716316 -79.239476            7.0   American Restaurant
# 6  43.692657 -79.264848            9.0       College Stadium
# 7  43.757410 -79.273304            4.0     Indian Restaurant
# 8  43.750072 -79.295849            4.0            Smoke Shop
# 9  43.781638 -79.304302            1.0              Pharmacy
#
#    2nd Most Common Venue      3rd Most Common Venue 4th Most Common Venue  \
# 0          Women's Store             Farmers Market    Falafel Restaurant
# 1                    Bar        Filipino Restaurant        Farmers Market
# 2         Breakfast Spot                        Spa        Medical Center
# 3             Hobby Shop                Coffee Shop      Department Store
# 4               Bus Line             Ice Cream Shop          Soccer Field
# 5                  Motel                Yoga Studio        Discount Store
# 6  General Entertainment                       Café          Skating Rink
# 7              Pet Store      Vietnamese Restaurant               Brewery
# 8         Breakfast Spot  Middle Eastern Restaurant                Bakery
# 9            Pizza Place                Gas Station  Fast Food Restaurant
#
#         5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                 Event Space  Ethiopian Restaurant     Electronics Store
# 1          Falafel Restaurant           Event Space  Ethiopian Restaurant
# 2           Electronics Store    Mexican Restaurant          Intersection
# 3                 Yoga Studio    Falafel Restaurant           Event Space
# 4                Intersection         Metro Station           Bus Station
# 5          Falafel Restaurant           Event Space  Ethiopian Restaurant
# 6  Construction & Landscaping        Discount Store    Falafel Restaurant
# 7          Chinese Restaurant                 Diner           Event Space
# 8         Distribution Center    Falafel Restaurant           Event Space
# 9         Rental Car Location                  Bank    Italian Restaurant
#
#          8th Most Common Venue        9th Most Common Venue  \
# 0  Eastern European Restaurant          Dumpling Restaurant
# 1            Electronics Store  Eastern European Restaurant
# 2                  Yoga Studio         Ethiopian Restaurant
# 3         Ethiopian Restaurant            Electronics Store
# 4                      Dog Run             Doner Restaurant
# 5            Electronics Store  Eastern European Restaurant
# 6                  Event Space         Ethiopian Restaurant
# 7         Ethiopian Restaurant            Electronics Store
# 8         Ethiopian Restaurant            Electronics Store
# 9           Chinese Restaurant              Thai Restaurant
#
#         10th Most Common Venue
# 0                   Donut Shop
# 1          Dumpling Restaurant
# 2  Eastern European Restaurant
# 3  Eastern European Restaurant
# 4                   Donut Shop
# 5          Dumpling Restaurant
# 6            Electronics Store
# 7  Eastern European Restaurant
# 8  Eastern European Restaurant
# 9          Fried Chicken Joint

# %% [markdown]
# Before we go on to the next step, we will have to conver the 'Cluster Labels' column to integer rather than floats. Otherwise, we will get an error when constructing the map. We will also remove any rows with NaN values which could interfere with the mapping part of our task.

# %%
toronto_merged = toronto_merged.dropna(axis = 0, how ='any').astype({'ClusterLabels': 'int64'})

# %% [markdown]
# ### Final Result!

# %% [markdown]
# For the last step, let us map out the resulting clusters.

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['ClusterLabels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Thank you for following along.
